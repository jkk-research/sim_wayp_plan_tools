# %%
import csv_manipulate

points = csv_manipulate.read_data('sim_waypoints1.csv')
csv_manipulate.plot_points(points)

# %%
points = csv_manipulate.read_data('sim_waypoints2.csv')
csv_manipulate.plot_points(points)

# %%
points = csv_manipulate.scale_points(points, 0.2)
points = csv_manipulate.rotate_points(points, 3.1416/3)
csv_manipulate.plot_points(points)
